# %% [markdown]
# # Analyze
#
# <hr style="clear:both">
# This notebook creates graphs that show the performances of our simulation. This way, we are able to compare different simulation under different conditions. For example, we can play with the objectives (minimize waiting time or detour time), change the maximum waiting/detour time or change the fleet size.
#
# **Authors:** [Lorenzo Ballinari](https://people.epfl.ch/lorenzo.ballinari), [Paulo Alexandre Ribeiro de Carvalho](https://people.epfl.ch/paulo.ribeirodecarvalho)
#
# <hr style="clear:both">

# %% [markdown]
# ## Librairies

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import data
#
# Please, use the variable "number" to choose the right data set to import. Every number correspond to a set of data that has been created under its specific <span style="color: #26B260">condition</span>.
#
# reference :
# 1. objectif function = **detour time** – fleet size = **2000[veh]** - maximum waiting time = **5[min]** – maximum detour time = **10[min]** – willingness to share = **80[%]**
#
# <hr style="clear:both">
#
# 2. objectif function = **detour time** – fleet size = **2000[veh]** - maximum waiting time = **5[min]** – maximum detour time = **10[min]** – willingness to share = **<span style="color: #26B260">100[%]</span>**
#
# <hr style="clear:both">
#
# 3_min. objectif function = **detour time** – fleet size = **2000[veh]** - maximum waiting time = **5[min]** – maximum detour time = **<span style="color: #26B260">3[min]</span>** – willingness to share = **80[%]**
#
# 3. objectif function = **detour time** – fleet size = **2000[veh]** - maximum waiting time = **5[min]** – maximum detour time = **<span style="color: #26B260">5[min]</span>** – willingness to share = **80[%]**
#
# 3_max. objectif function = **detour time** – fleet size = **2000[veh]** - maximum waiting time = **5[min]** – maximum detour time = **<span style="color: #26B260">7[min]</span>** – willingness to share = **80[%]**
#
# 4. objectif function = **detour time** – fleet size = **2000[veh]** - maximum waiting time = **5[min]** – maximum detour time = **<span style="color: #26B260">10[min]</span>** – willingness to share = **80[%]**
#
# 5. objectif function = **detour time** – fleet size = **2000[veh]** - maximum waiting time = **5[min]** – maximum detour time = **<span style="color: #26B260">15[min]</span>** – willingness to share = **80[%]**
#
# 6. objectif function = **detour time** – fleet size = **2000[veh]** - maximum waiting time = **5[min]** – maximum detour time = **<span style="color: #26B260">20[min]</span>** – willingness to share = **80[%]**
#
# <hr style="clear:both">
#
# 7_min. objectif function = **waiting time** – fleet size = **2000[veh]** - maximum waiting time = **<span style="color: #26B260">3[min]</span>** – maximum detour time = **10[min]** – willingness to share = **80[%]**
#
# 7. objectif function = **waiting time** – fleet size = **2000[veh]** - maximum waiting time = **<span style="color: #26B260">5[min]</span>** – maximum detour time = **10[min]** – willingness to share = **80[%]**
#
# 7_max. objectif function = **waiting time** – fleet size = **2000[veh]** - maximum waiting time = **<span style="color: #26B260">7[min]</span>** – maximum detour time = **10[min]** – willingness to share = **80[%]**
#
# 8. objectif function = **waiting time** – fleet size = **2000[veh]** - maximum waiting time = **<span style="color: #26B260">9[min]</span>** – maximum detour time = **10[min]** – willingness to share = **80[%]**
#
# 9. objectif function = **waiting time** – fleet size = **2000[veh]** - maximum waiting time = **<span style="color: #26B260">12[min]</span>** – maximum detour time = **10[min]** – willingness to share = **80[%]**
#
# 10. objectif function = **waiting time** – fleet size = **2000[veh]** - maximum waiting time = **<span style="color: #26B260">15[min]</span>** – maximum detour time = **10[min]** – willingness to share = **80[%]**
#
# <hr style="clear:both">
#
# 11. objectif function = **maximize ass.** – fleet size = **2000[veh]** - maximum waiting time = **5[min]** – maximum detour time = **10[min]** – willingness to share = **<span style="color: #26B260">0[%]</span>**
#
# 12. objectif function = **maximize ass.** – fleet size = **2000[veh]** - maximum waiting time = **5[min]** – maximum detour time = **10[min]** – willingness to share = **<span style="color: #26B260">50[%]</span>**
#
# 13. objectif function = **maximize ass.** – fleet size = **2000[veh]** - maximum waiting time = **5[min]** – maximum detour time = **10[min]** – willingness to share = **<span style="color: #26B260">100[%]</span>**
#
# <hr style="clear:both">
#
# 14. objectif function = **maximize ass.** – fleet size = **<span style="color: #26B260">1800[veh]</span>** - maximum waiting time = **5[min]** – maximum detour time = **10[min]** – willingness to share = **80[%]**
#
# 15. objectif function = **maximize ass.** – fleet size = **<span style="color: #26B260">2000[veh]</span>** - maximum waiting time = **5[min]** – maximum detour time = **10[min]** – willingness to share = **80[%]**
#
# 16. objectif function = **maximize ass.** – fleet size = **<span style="color: #26B260">2300[veh]</span>** - maximum waiting time = **5[min]** – maximum detour time = **10[min]** – willingness to share = **80[%]**
#
# <hr style="clear:both">
#
# The second part of our work consist to check if the matching of sharing trips and non sharing trips will be more efficient if they are done at the same time. This new code give us simulation that takes a few hours. For the project, it has been choose to reduce the number of request recieve during the simulation. These are the new conditions :
#
# 1_reduce. objectif function = **detour time** – fleet size = **500[veh]** - maximum waiting time = **5[min]** – maximum detour time = **<span style="color: #26B260">5[min]</span>** – willingness to share = **80[%]**
#
# 2_reduce. objectif function = **detour time** – fleet size = **500[veh]** - maximum waiting time = **5[min]** – maximum detour time = **<span style="color: #26B260">10[min]</span>** – willingness to share = **80[%]**
#
# 3_reduce. objectif function = **detour time** – fleet size = **500[veh]** - maximum waiting time = **5[min]** – maximum detour time = **<span style="color: #26B260">15[min]</span>** – willingness to share = **80[%]**
#
# 4_reduce. objectif function = **detour time** – fleet size = **500[veh]** - maximum waiting time = **5[min]** – maximum detour time = **<span style="color: #26B260">20[min]</span>** – willingness to share = **80[%]**

# %%
number = '7_min'
version = 'separate' # algo -> 'same_time' or 'separate'
extension = '' # extension de nom de fichier -> '_s_t' or ''

Occupancy_perf = np.load(f"Results_{version}/condition_{number}/Occupancy_perf_condition_{number}{extension}.npy")
Abandonment_perf = np.load(f"Results_{version}/condition_{number}/Abandonment_perf_condition_{number}{extension}.npy")
Waiting_time_perf = np.load(f"Results_{version}/condition_{number}/Waiting_time_perf_condition_{number}{extension}.npy")
Detour_time_perf = np.load(f"Results_{version}/condition_{number}/Detour_time_perf_condition_{number}{extension}.npy")
history_sharing = np.load(f"Results_{version}/condition_{number}/history_sharing_condition_{number}{extension}.npy")

Time = [i for i in range(len(Occupancy_perf[0]))]

# print("occupancy performance : ",Occupancy_perf.shape,type(Occupancy_perf),"\n",Occupancy_perf, "\n")
# print("abandonment performance : ",Abandonment_perf.shape,type(Abandonment_perf),"\n",Abandonment_perf,"\n")
# print("waiting time performance : ",Waiting_time_perf.shape,type(Waiting_time_perf),"\n",Waiting_time_perf,"\n")
# print("detour performance : ",Detour_time_perf.shape,type(Detour_time_perf),"\n",Detour_time_perf, "\n")
# print("history sharing : ",history_sharing.shape,type(history_sharing),"\n",history_sharing, "\n")

# %% [markdown]
# ## Graphs
#
# Run all the following cells to compute the different graphs.

# %% [markdown]
# #### Occupancy

# %%
plt.figure(1)

plt.plot(Time, Occupancy_perf[0])
plt.plot(Time, Occupancy_perf[1])
plt.plot(Time, Occupancy_perf[2])
plt.title('Occupancy during simulation')
plt.legend(['Occupancy of vehicles = 0', 'Occupancy of vehicles = 1', 'Occupancy of vehicles = 2'])
plt.xlabel('Time step')
plt.ylabel('Number of vehicules')
plt.show()

# %% [markdown]
# #### Abandonment

# %%
plt.figure(2)

plt.plot(Time, Abandonment_perf)
plt.title('Abandonment')
plt.xlabel('Time step')
plt.ylabel('Abandonment')
plt.show()

print(f'abandonment {int(Abandonment_perf[-1])} requests')
# Out:
# abandonment 1326 requests

# %% [markdown]
# #### Waiting Time

# %%
plt.figure(3)

Request_w = [i for i in range(len(Waiting_time_perf))]
mean_w = np.ones([len(Waiting_time_perf)])*np.mean(Waiting_time_perf)*60
plt.scatter(Request_w, Waiting_time_perf*60,s=0.2)
plt.plot(Request_w, mean_w, color='orange')
plt.title('Waiting Time [min]')
plt.xlabel('Requests')
plt.ylabel('Waiting time [min]')
plt.legend(['waiting times','mean'])
plt.show()

print(f'mean waiting time : {mean_w[0]:.4f}[min]')
print(len(Waiting_time_perf))
# Out:
# mean waiting time : 1.0903[min]
# 30320

# %% [markdown]
# #### Detour Time

# %%
if len(Detour_time_perf) == 0:
    print('No sharing trips, so no detour time saved.')
    
else :
    plt.figure(4)

    Request_d = [i for i in range(len(Detour_time_perf))]
    mean_d = np.ones([len(Detour_time_perf)])*np.mean(Detour_time_perf)*60
    plt.scatter(Request_d, Detour_time_perf*60,s=1)
    plt.plot(Request_d, mean_d, color='orange')
    plt.title('Detour Time')
    plt.xlabel('Requests')
    plt.ylabel('Detour time [min]')
    plt.show()

    print(f'mean detour time : {mean_d[0]:.4f}[min]')
# Out:
# mean detour time : 2.9245[min]

# %%
number_exeed = []


for i in range(len(Detour_time_perf)):
    if Detour_time_perf[i]*60>20:
        number_exeed.append(i)
        
print(len(number_exeed))
# Out:
# 0

# %%
for e in number_exeed:
    print(history_sharing[e+1,2],Detour_time_perf[e]*60)

# %% [markdown]
# #### Shared Trips

# %%
number_request_total = len(Waiting_time_perf)
number_request_shared = len(Detour_time_perf)

percentage_shared_trip = number_request_shared/number_request_total

print(f'% of shared trips for the simulation : {percentage_shared_trip*100:.2f}[%]')
# Out:
# % of shared trips for the simulation : 70.71[%]
